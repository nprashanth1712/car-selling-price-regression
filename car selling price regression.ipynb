# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\navug\Downloads\CAR DETAILS FROM CAR DEKHO (1).csv")

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
df.drop(columns='name',inplace=True)

# %%
df['fuel'].value_counts()
# Out:
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: fuel, dtype: int64

# %%
df['fuel'].replace({'Diesel':0,'Petrol':1,'CNG':2,'LPG':3,'Electric':4},inplace=True)

# %%
df
# Out:
#       year  selling_price  km_driven  fuel seller_type transmission  \
# 0     2007          60000      70000     1  Individual       Manual
# 1     2007         135000      50000     1  Individual       Manual
# 2     2012         600000     100000     0  Individual       Manual
# 3     2017         250000      46000     1  Individual       Manual
# 4     2014         450000     141000     0  Individual       Manual
# ...    ...            ...        ...   ...         ...          ...
# 4335  2014         409999      80000     0  Individual       Manual
# 4336  2014         409999      80000     0  Individual       Manual
# 4337  2009         110000      83000     1  Individual       Manual
# 4338  2016         865000      90000     0  Individual       Manual
# 4339  2016         225000      40000     1  Individual       Manual
#
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# 3      First Owner
# 4     Second Owner
# ...            ...
# ...

# %%
df['transmission'].value_counts()
# Out:
# Manual       3892
# Automatic     448
# Name: transmission, dtype: int64

# %%
df['transmission'].replace({'Manual':0,'Automatic':1},inplace=True)

# %%
df
# Out:
#       year  selling_price  km_driven  fuel seller_type  transmission  \
# 0     2007          60000      70000     1  Individual             0
# 1     2007         135000      50000     1  Individual             0
# 2     2012         600000     100000     0  Individual             0
# 3     2017         250000      46000     1  Individual             0
# 4     2014         450000     141000     0  Individual             0
# ...    ...            ...        ...   ...         ...           ...
# 4335  2014         409999      80000     0  Individual             0
# 4336  2014         409999      80000     0  Individual             0
# 4337  2009         110000      83000     1  Individual             0
# 4338  2016         865000      90000     0  Individual             0
# 4339  2016         225000      40000     1  Individual             0
#
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# 3      First Owner
# 4     Second Owner
# ...

# %%
df['owner'].value_counts()
# Out:
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: owner, dtype: int64

# %%
df['owner'].replace({'First Owner':0,'Second Owner':1,'Third Owner':2,'Fourth & Above Owner':3,'Test Drive Car':4},inplace=True)

# %%
df
# Out:
#       year  selling_price  km_driven  fuel seller_type  transmission  owner
# 0     2007          60000      70000     1  Individual             0      0
# 1     2007         135000      50000     1  Individual             0      0
# 2     2012         600000     100000     0  Individual             0      0
# 3     2017         250000      46000     1  Individual             0      0
# 4     2014         450000     141000     0  Individual             0      1
# ...    ...            ...        ...   ...         ...           ...    ...
# 4335  2014         409999      80000     0  Individual             0      1
# 4336  2014         409999      80000     0  Individual             0      1
# 4337  2009         110000      83000     1  Individual             0      1
# 4338  2016         865000      90000     0  Individual             0      0
# 4339  2016         225000      40000     1  Individual             0      0
#
# [4340 rows x 7 columns]

# %%
import seaborn as sns

# %%
sns.barplot(x='fuel',y='selling_price',data=df)
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='selling_price'>

# %%
sns.barplot(x='transmission',y='selling_price',data=df)
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='selling_price'>

# %%
df['km_driven'].min()
# Out:
# 1

# %%
min_value=df[df['km_driven']<=1]

# %%
min_value
# Out:
#       year  selling_price  km_driven  fuel seller_type  transmission  owner
# 1312  2014         250000          1     0  Individual             0      1

# %%
sns.barplot(x='year',y='selling_price',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='selling_price'>

# %%
df[df['km_driven']<=1000]
# Out:
#       year  selling_price  km_driven  fuel seller_type  transmission  owner
# 552   2013         450000       1000     0      Dealer             0      1
# 571   2013         450000       1000     0      Dealer             0      1
# 590   2013         450000       1000     0      Dealer             0      1
# 609   2013         450000       1000     0      Dealer             0      1
# 897   2013         450000       1000     0      Dealer             0      1
# 916   2013         450000       1000     0      Dealer             0      1
# 1291  2020         350000       1000     1  Individual             0      0
# 1312  2014         250000          1     0  Individual             0      1
# 1714  2020         784000        101     0      Dealer             0      4
# 1715  2020         635000        101     1      Dealer             0      4
# 1716  2020        1000000        101     0      Dealer             0      4
# ...

# %%
df['km_driven'].max()
# Out:
# 806599

# %%
df.drop(1312,axis=0,inplace=True)

# %%
df
# Out:
#       year  selling_price  km_driven  fuel seller_type  transmission  owner
# 0     2007          60000      70000     1  Individual             0      0
# 1     2007         135000      50000     1  Individual             0      0
# 2     2012         600000     100000     0  Individual             0      0
# 3     2017         250000      46000     1  Individual             0      0
# 4     2014         450000     141000     0  Individual             0      1
# ...    ...            ...        ...   ...         ...           ...    ...
# 4335  2014         409999      80000     0  Individual             0      1
# 4336  2014         409999      80000     0  Individual             0      1
# 4337  2009         110000      83000     1  Individual             0      1
# 4338  2016         865000      90000     0  Individual             0      0
# 4339  2016         225000      40000     1  Individual             0      0
#
# [4339 rows x 7 columns]

# %%
df['km_driven'].min()
# Out:
# 101

# %%
df
# Out:
#       year  selling_price  km_driven  fuel seller_type  transmission  owner
# 0     2007          60000      70000     1  Individual             0      0
# 1     2007         135000      50000     1  Individual             0      0
# 2     2012         600000     100000     0  Individual             0      0
# 3     2017         250000      46000     1  Individual             0      0
# 4     2014         450000     141000     0  Individual             0      1
# ...    ...            ...        ...   ...         ...           ...    ...
# 4335  2014         409999      80000     0  Individual             0      1
# 4336  2014         409999      80000     0  Individual             0      1
# 4337  2009         110000      83000     1  Individual             0      1
# 4338  2016         865000      90000     0  Individual             0      0
# 4339  2016         225000      40000     1  Individual             0      0
#
# [4339 rows x 7 columns]

# %%
x=df.drop(columns=['selling_price','seller_type'])

# %%
y=df['selling_price']

# %%
x
# Out:
#       year  km_driven  fuel  transmission  owner
# 0     2007      70000     1             0      0
# 1     2007      50000     1             0      0
# 2     2012     100000     0             0      0
# 3     2017      46000     1             0      0
# 4     2014     141000     0             0      1
# ...    ...        ...   ...           ...    ...
# 4335  2014      80000     0             0      1
# 4336  2014      80000     0             0      1
# 4337  2009      83000     1             0      1
# 4338  2016      90000     0             0      0
# 4339  2016      40000     1             0      0
#
# [4339 rows x 5 columns]

# %%
y
# Out:
# 0        60000
# 1       135000
# 2       600000
# 3       250000
# 4       450000
#          ...
# 4335    409999
# 4336    409999
# 4337    110000
# 4338    865000
# 4339    225000
# Name: selling_price, Length: 4339, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x.describe(
)
# Out:
#               year      km_driven         fuel  transmission        owner
# count  4339.000000    4339.000000  4339.000000    4339.00000  4339.000000
# mean   2013.090574   66231.037797     0.524545       0.10325     0.466467
# std       4.215807   46638.641481     0.549977       0.30432     0.740371
# min    1992.000000     101.000000     0.000000       0.00000     0.000000
# 25%    2011.000000   35000.000000     0.000000       0.00000     0.000000
# 50%    2014.000000   60000.000000     1.000000       0.00000     0.000000
# 75%    2016.000000   90000.000000     1.000000       0.00000     1.000000
# max    2020.000000  806599.000000     4.000000       1.00000     4.000000

# %%
x_train.shape
# Out:
# (3471, 5)

# %%
model_reg=LinearRegression()

# %%
model_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn import metrics

# %%
x_trainpredict=model_reg.predict(x_train)

# %%
x_trainpredict.shape
# Out:
# (3471,)

# %%
x_testpredict=model_reg.predict(x_test)

# %%
x_testpredict.shape
# Out:
# (868,)

# %%
acc_mark=metrics.r2_score(y_test,x_testpredict)

# %%
print(acc_mark)
# Out:
# 0.3871153379165154

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_train,x_trainpredict)
plt.xlabel('actual price')
plt.ylabel('predicted price')
plt.show()
